# %% [markdown]
# # 命名空间和作用域
# 在 Python 编程中，命名空间（namespace）是一个非常重要的概念，它为变量、函数、类等命名提供了管理机制，确保名称的唯一性，避免命名冲突。各个命名空间是独立的，一个命名空间中不能有重名，但不同的命名空间是可以重名的。这个跟计算机文件系统的例子很像，一个文件夹(目录)中可以包含多个文件夹，每个文件夹中不能有相同的文件名，但不同文件夹中的文件可以重名。
#
# 在Python中，通常分为三种命名空间：
# - 内置命名空间（built-in namespace）：Python 解释器启动时创建，包含所有内置的函数和异常，如 print()、len() 等。该命名空间在解释器关闭时销毁。
# - 全局命名空间（global namespace）：每个模块都有自己的全局命名空间，包含模块级的变量、函数和类。全局命名空间在模块被导入时创建，在模块卸载时销毁。
# - 局部命名空间（local namespace）：函数或方法被调用时创建，包含函数内部定义的变量和参数。局部命名空间在函数调用结束时销毁。
#
# Python 采用 LEGB 规则来查找名称，假设我们要使用变量 username，则 Python 的查找顺序为：局部命名空间（Local） ->闭包函数的外部函数的命名空间（Enclosing） -> 全局命名空间（Global） -> 内置命名空间（Built-in）。如果找不到变量 username，则会报 NameError 异常：`NameError: name 'test_name' is not defined`。
#
# 命名空间的生命周期：
# 命名空间的生命周期取决于对象的作用域，如果对象执行完成，则该命名空间的生命周期就结束。因此，我们无法从外部命名空间访问内部命名空间的对象。

# %%
https://www.cnblogs.com/xtcoding/p/19022652

https://geek-blogs.com/blog/python-namespace/

https://blog.csdn.net/weixin_47021806/article/details/109350259

# %% [markdown]
# ## 1.查看命名空间
# Python 提供了两个内置函数用于查看当前命名空间的内容：
#
# - locals()：返回当前局部命名空间的字典（可修改，修改会影响局部变量）。
# - globals()：返回当前全局命名空间的字典（修改会影响全局变量）。
